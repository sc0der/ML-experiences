# %%
import numpy as np

# %%
mylist = [1, 2, 4]

# %%
myarr = np.array(mylist)
type(myarr)
# Out:
# numpy.ndarray

# %%
np.zeros((2, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2, 3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.linspace(0, 10, 11)
# Out:
# array([ 0.,  5., 10.])
