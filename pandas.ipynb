# %%
"Series - Это структура данных в Pandas, которая массив данных а также именованный индекс"
# Out:
# 'Series - Это структура данных в Pandas, которая массив данных а также именованный индекс'

# %%
import numpy as np

# %%
import pandas as pd

# %%
# help(pd.Series)

# %%
indexes = ['Dushanbe', 'Khujand', 'Panjakent', 'Kulob']

# %%
datas = [1000, 900, 800, 700]

# %%
realise = pd.Series(data=datas, index=indexes)

# %%
realise
# Out:
# Dushanbe     1000
# Khujand       900
# Panjakent     800
# Kulob         700
# dtype: int64
